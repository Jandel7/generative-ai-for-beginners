# %%
import os
print("AZURE_OPENAI_ENDPOINT value:", repr(os.getenv("AZURE_OPENAI_ENDPOINT")))
# Out:
# AZURE_OPENAI_ENDPOINT value: 'https://jande-mhkpgxs4-eastus2.cognitiveservices.azure.com/'

# %%
import os
import openai

openai.api_type = "azure"
openai.api_version = os.getenv("AZURE_OPENAI_API_VERSION","").strip()

API_KEY = os.getenv("AZURE_OPENAI_API_KEY","").strip()
assert API_KEY, "ERROR: Azure OpenAI Key is missing"
openai.api_key = API_KEY

RESOURCE_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
openai.api_base = RESOURCE_ENDPOINT
deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT", "").strip()
assert deployment, "ERROR: Azure OpenAI Deployment name is missing"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 13
#      11 RESOURCE_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT","").strip()
#      12 assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
# ---> 13 assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
#      14 openai.api_base = RESOURCE_ENDPOINT
#      15 deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT", "").strip()
#
# AssertionError: ERROR: Azure OpenAI Endpoint should be in the form:
#
# 	<your unique endpoint identifier>.openai.azure.com

# %%
# Create your first prompt
text_prompt = " My foot hurts, what can be wrong?"

response = openai.ChatCompletion.create(
  engine=deployment,
  messages = [
      {"role":"system", "content":"I'm a doctor, specialist on surgery"},
      {"role":"user","content":text_prompt},])


response['choices'][0]['message']['content']
